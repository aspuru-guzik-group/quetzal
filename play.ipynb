# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
DIFF_STEPS = 60
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
from train import Config, LitQuetzal

### qm9
kwargs = {
    "bsz": 10000,
    "device": DEVICE,
    "num_steps": DIFF_STEPS,
    "pbar": True,
    "max_len": 32,
}
ckpt_name = "original" # best, largest qm9 checkpoint, corresponds to big_w1536
# pick one of: small_w512 small_w1024 small_w1536 base_w512 base_w1024 base_w1536 big_w512 big_w1024 original random_order no_rotate_translate

### geom
# kwargs = {
#     "bsz": 1000,
#     "device": DEVICE,
#     "num_steps": DIFF_STEPS,
#     "pbar": True,
#     "max_len": 192,
# }
# ckpt_name = "geom"

ckpt = f"checkpoints/{ckpt_name}.ckpt"
lit = LitQuetzal.load_from_checkpoint(ckpt, map_location=DEVICE)
model = lit.ema.module
model.eval();

out = model.generate(**kwargs)
samples, all_traj = out
# Out:
#  91%|█████████ | 29/32 [01:42<00:10,  3.53s/it]

# %%
from metrics import compute_valid_unique
compute_valid_unique(samples.unbatch())
# validity, uniqueness
# Out:
# (0.9901, 0.9476820523179477)

# %%
from draw import show_grid
show_grid(samples, 5, 5, offset=50)
# Out:
# <div id="3dmolviewer_17571263021292179"  style="position: relative; width: 1000px; height: 1000px;">
#         <p id="3dmolwarning_17571263021292179" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %%
from draw import show_traj

show_traj(out, b_idx=50, interval=10)
# Out:
# <div id="3dmolviewer_17571263024858296"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17571263024858296" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...
